# %% [markdown]
# **Program**: 5_NSCH_Naive_Bayes_Analysis<br>
# **Class**: Fall 2025, Machine Learning, Project<br>
# **Member**: Vanessa Thorsten<br>
# **Description**: This program reads in the analysis dataset NSCH_fam.csv, which provides data at the child-level and requires weighting the data due to the sampling and response. Variables are kept and Random Forest analysis is performed.<br>
# <br>
# **Outputs**: The following data visualizations are provided for the dataset:<br>
# 'Q9_AdeqSleep_MNB_features.png'<br>
# 'Q9_AdeqSleep_MNB_CM_Original.png'<br>
# 'Q9_AdeqSleep_MNB_Threshold_Tuning.png'<br>
# 'Q9_AdeqSleep_MNB_PrecRecall.png'<br>
# 'Q9_AdeqSleep_MNB_CM_ReviseThreshold.png'<br>
# 'Q9_AdeqSleep_MNB_ROC.png'<br>
# 'Q9_AdeqSleep_MNB_LogProb.png'<br>
# <br>
# **Program History/Modifications**:<br>
# 10/14/2025    Initial Version

# %%
# Importing the libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math

from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import roc_auc_score, roc_curve, confusion_matrix, accuracy_score, f1_score, recall_score, classification_report
from sklearn.metrics import make_scorer #use for weighted roc auc
from sklearn.tree import plot_tree

from sklearn.inspection import PartialDependenceDisplay

# %%
#Combined state level data
df_fam = pd.read_csv("NSCH_fam.csv")
df_fam.head()
# Out:
#    Unnamed: 0  FIPSST STATE  STATE_NAME  STRATUM      HHID  FORMTYPE  \
# 0           0       6    CA  California        1  23043707         2
# 1           1       6    CA  California        1  23120547         3
# 2           2       6    CA  California        1  23197456         3
# 3           3       6    CA  California        1  23197458         3
# 4           4       6    CA  California        1  23235909         2
#
#    TOTKIDS_R          FWC  SC_AGE_YEARS  ...  K4Q01  GOWHENSICK  UsualSck_23  \
# 0          1  1318.476840            11  ...    2.0         NaN          2.0
# 1          2   978.499881            14  ...    1.0         1.0          1.0
# 2          1   904.191765            17  ...    1.0         NaN          NaN
# 3          2  1092.097256            12  ...    1.0         1.0          1.0
# 4          2   586.387870            10  ...    2.0         NaN          2.0
#
#    smAdeqIns_23  smForgoneHC_23  nomAnxietyDep12to17_23  nomFlrish6mto5_23  \
# 0           1.0             2.0                     NaN               90.0
# 1           1.0             2.0                     2.0               90.0
# 2           1.0             2.0                     2.0               90.0
# 3           1.0             2.0                     2.0               90.0
# 4           2.0             2.0                     NaN               90.0
#
#    nomFlrish6to17_23  ScreenTime_23  HrsSleep_23
# 0                2.0            4.0          2.0
# 1                1.0            5.0          1.0
# 2                1.0            4.0          1.0
# 3                1.0            4.0          1.0
# 4                1.0            5.0          1.0
#
# [5 rows x 44 columns]

# %%
df_fam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54159 entries, 0 to 54158
# Data columns (total 44 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              54159 non-null  int64
#  1   FIPSST                  54159 non-null  int64
#  2   STATE                   54159 non-null  object
#  3   STATE_NAME              54159 non-null  object
#  4   STRATUM                 54159 non-null  int64
#  5   HHID                    54159 non-null  int64
#  6   FORMTYPE                54159 non-null  int64
#  7   TOTKIDS_R               54159 non-null  int64
#  8   FWC                     54159 non-null  float64
#  9   SC_AGE_YEARS            54159 non-null  int64
#  10  SC_SEX                  54159 non-null  int64
#  11  age3_23                 54159 non-null  int64
#  12  age5_23                 54159 non-null  int64
#  13  sex_23                  54159 non-null  int64
#  14  hispanic_23             54159 non-null  int64
#  15  race4_23                54159 non-null  int64
#  16  raceASIA_23             54159 non-null  int64
#  17  race7_23                54159 non-null  int64
#  18  PlacesLived_23          52739 non-null  float64
#  19  HousingInstab_23        53140 non-null  float64
#  20  FoodCash_23             53137 non-null  float64
#  21  WIC_23                  52887 non-null  float64
#  22  povlev4_23              54159 non-null  int64
#  23  povSCHIP_23             54159 non-null  int64
#  24  AdultEduc_23            54159 non-null  int64
#  25  BornUSA_23              53919 non-null  float64
#  26  FamCount_23             52375 non-null  float64
#  27  K2Q01                   54159 non-null  float64
#  28  ChHlthSt_23             54159 non-null  float64
#  29  nomChHlthSt_23          54159 non-null  float64
#  30  MedCare_23              54152 non-null  float64
#  31  PrevMed_23              54159 non-null  float64
#  32  PrevDent_23             52124 non-null  float64
#  33  MedDentCare_23          54045 non-null  float64
#  34  K4Q01                   54159 non-null  float64
#  35  GOWHENSICK              44870 non-null  float64
#  36  UsualSck_23             53828 non-null  float64
#  37  smAdeqIns_23            54159 non-null  float64
#  38  smForgoneHC_23          54021 non-null  float64
#  39  nomAnxietyDep12to17_23  17833 non-null  float64
#  40  nomFlrish6mto5_23       53074 non-null  float64
#  41  nomFlrish6to17_23       53993 non-null  float64
#  42  ScreenTime_23           53410 non-null  float64
#  43  HrsSleep_23             53103 non-null  float64
# dtypes: float64(24), int64(18), object(2)
# memory usage: 18.2+ MB

# %%
# Outcome of interest is teens geeting adequate sleep for their age.
# Filter the data to teens
df_teen = df_fam[df_fam['SC_AGE_YEARS'] > 12].copy()

# %%
#Add labeled variable for graphs
hrssleep_labels = {
    1: 'Adequate for age',
    2: 'Inadequate for age'
}

hrssleep_order = ['Adequate for age', 'Inadequate for age']

df_teen['HrsSleep_labeled'] = df_teen['HrsSleep_23'].map(hrssleep_labels)

#Add 0/1 variable for models. 1 -> 0 (adequate sleep), 2 -> 1 (inadequate sleep), NAN stays NAN
df_teen['inadequate_sleep'] = df_teen['HrsSleep_23'].map({1: 0, 2: 1}).astype('Int64')

# %%
cols = ['HrsSleep_23', 'inadequate_sleep', 'K2Q01', 'ScreenTime_23', 'FoodCash_23', 'FamCount_23', 'AdultEduc_23']

for col in cols:
    print(f"{df_teen[col].value_counts()}\n")

# FoodCash_23 is 1= someone in house received food/cash assistance during the past 12 months from 3-5 sources
#                2= someone in house received food/cash assistance during the past 12 months from 1-2 sources
#                3= did not receive food/cash assistance during the past 12 months
# Out:
# HrsSleep_23
# 1.0    10980
# 2.0     4272
# Name: count, dtype: int64
#
# inadequate_sleep
# 0    10980
# 1     4272
# Name: count, dtype: Int64
#
# K2Q01
# 1.0    9301
# 2.0    4307
# 3.0    1476
# 4.0     283
# 5.0      24
# Name: count, dtype: int64
#
# ScreenTime_23
# 5.0    5631
# 3.0    3956
# 4.0    3943
# 2.0    1211
# 1.0     468
# Name: count, dtype: int64
#
# FoodCash_23
# 1.0    10105
# 2.0     4015
# 3.0     1002
# Name: count, dtype: int64
#
# FamCount_23
# 3.0    5271
# 2.0    4783
# 4.0    2307
# 1.0    1366
# 5.0    1151
# Name: count, dtype: int64
#
# AdultEduc_23
# 4    9392
# 3    3320
# 2    2173
# 1     506
# Name: count, dtype: int64

# %%
# Using isna() to count NaNs in each column
column_nan_count_isna = df_teen[['HrsSleep_23', 'K2Q01', 'ScreenTime_23', 'FoodCash_23', 
                                 'FamCount_23', 'AdultEduc_23', 'FWC']].isna().sum()
print("NaN count per column using isna():") 
print(column_nan_count_isna)
# Out:
# NaN count per column using isna():
# HrsSleep_23      139
# K2Q01              0
# ScreenTime_23    182
# FoodCash_23      269
# FamCount_23      513
# AdultEduc_23       0
# FWC                0
# dtype: int64

# %%
# Subset to relevant variables
df_teen_rf = df_teen[['inadequate_sleep', 'HrsSleep_23', 'HrsSleep_labeled', 'K2Q01', 'ScreenTime_23', 'FoodCash_23', 'FamCount_23', 'AdultEduc_23', 'FWC']].copy()

# Fill missing values with the mode (most frequent value) for each column
for col in df_teen_rf.columns:
    mode = df_teen_rf[col].mode(dropna=True)
    if not mode.empty:
        df_teen_rf[col] = df_teen_rf[col].fillna(mode[0])
    else:
        print(f"Warning: No mode found for column '{col}' — possibly all NaNs.")

# %%
#convert from float to int
cols_to_convert = ['HrsSleep_23','K2Q01', 'ScreenTime_23', 'FoodCash_23', 'FamCount_23', 'AdultEduc_23']

df_teen_rf[cols_to_convert] = df_teen_rf[cols_to_convert].astype('int64')

# %%
column_nan_count_isna = df_teen_rf[['inadequate_sleep', 'HrsSleep_23', 'K2Q01', 'ScreenTime_23', 'FoodCash_23', 
                                    'FamCount_23', 'AdultEduc_23', 'FWC']].isna().sum()
print("NaN count per column using isna():") 
print(column_nan_count_isna)
# Out:
# NaN count per column using isna():
# inadequate_sleep    0
# HrsSleep_23         0
# K2Q01               0
# ScreenTime_23       0
# FoodCash_23         0
# FamCount_23         0
# AdultEduc_23        0
# FWC                 0
# dtype: int64

# %%
df_teen_rf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15391 entries, 1 to 54152
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   inadequate_sleep  15391 non-null  Int64
#  1   HrsSleep_23       15391 non-null  int64
#  2   HrsSleep_labeled  15391 non-null  object
#  3   K2Q01             15391 non-null  int64
#  4   ScreenTime_23     15391 non-null  int64
#  5   FoodCash_23       15391 non-null  int64
#  6   FamCount_23       15391 non-null  int64
#  7   AdultEduc_23      15391 non-null  int64
#  8   FWC               15391 non-null  float64
# dtypes: Int64(1), float64(1), int64(6), object(1)
# memory usage: 1.2+ MB

# %%
vars_to_plot = [
    'K2Q01', 'ScreenTime_23', 'FoodCash_23', 'FamCount_23', 'AdultEduc_23'
]

n_vars = len(vars_to_plot)
cols = 3
rows = math.ceil(n_vars / cols)

fig, axes = plt.subplots(rows, cols, figsize=(cols*6, rows*4), constrained_layout=True)
axes = axes.flatten()

for i, var in enumerate(vars_to_plot):
    ax = axes[i]

    # Calculate weighted counts by variable and hue
    weighted_counts = (
        df_teen_rf
        .groupby([var, 'HrsSleep_labeled'], dropna=False)['FWC']
        .sum()
        .reset_index()
        .rename(columns={'FWC': 'weighted_count'})
    )

    # Calculate total weighted counts per variable value
    total_counts = (
        weighted_counts
        .groupby(var)['weighted_count']
        .sum()
        .reset_index()
        .rename(columns={'weighted_count': 'total_weighted_count'})
    )

    # Merge totals back to weighted_counts to calculate proportions
    merged = weighted_counts.merge(total_counts, on=var)
    merged['prop'] = merged['weighted_count'] / merged['total_weighted_count']

    # Pivot for plotting stacked bars
    pivot_df = merged.pivot(index=var, columns='HrsSleep_labeled', values='prop').fillna(0)

    # Sort index if possible (depends on your data type)
    pivot_df = pivot_df.sort_index()

    # Plot stacked bar
    pivot_df.plot(kind='bar', stacked=True, ax=ax, colormap='Set2', edgecolor='black')

    ax.set_title(f"Weighted Proportion of {var} by Hours of Sleep")
    ax.set_xlabel(var)
    ax.set_ylabel("Weighted Proportion")
    ax.legend(title='HrsSleep_23')

# Hide unused subplots
for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.suptitle('Weighted Proportions of Variables by HrsSleep Categories', fontsize=16, y=1.02)

# Save plot
plt.savefig('Q9_AdeqSleep_MNB_features.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
df_teen_rf['inadequate_sleep'].value_counts()
# Out:
# inadequate_sleep
# 0    11119
# 1     4272
# Name: count, dtype: Int64

# %%
# Displaying the data before splitting
# Keep features that are count variables or scales for the multinomial analysis
features = ['K2Q01', 'ScreenTime_23', 'FoodCash_23', 'FamCount_23', 'AdultEduc_23']

target = 'inadequate_sleep'

FWC = df_teen_rf['FWC']

display(df_teen_rf[features].head())
display(df_teen_rf[target].head())
# Out:
#    K2Q01  ScreenTime_23  FoodCash_23  FamCount_23  AdultEduc_23
# 1      2              5            2            3             4
# 2      3              4            2            4             2
# 5      1              3            3            5             4
# 6      2              4            2            2             4
# 9      1              5            1            1             3
# 1    0
# 2    0
# 5    0
# 6    0
# 9    1
# Name: inadequate_sleep, dtype: Int64

# %%
# Splitting the dataset into the Training set and Test set
# Add stratify=y to maintain class-balanced split, maintain label proportions and improve reliability

X_train, X_test, y_train, y_test, FWC_train, FWC_test = train_test_split(df_teen_rf[features],df_teen_rf[target],FWC, 
                                                                         test_size=0.3,random_state=4567, stratify=df_teen_rf[target])

# %%
# For training set
train_counts = y_train.value_counts()
train_percentages = y_train.value_counts(normalize=True) * 100
train_summary = pd.DataFrame({'Count': train_counts, 'Percentage': train_percentages.round(2)})
print("Training Set Class Distribution:")
display(train_summary)

# For test set
test_counts = y_test.value_counts()
test_percentages = y_test.value_counts(normalize=True) * 100
test_summary = pd.DataFrame({'Count': test_counts, 'Percentage': test_percentages.round(2)})
print("Test Set Class Distribution:")
display(test_summary)
# Out:
# Training Set Class Distribution:
#                   Count  Percentage
# inadequate_sleep
# 0                  7783       72.25
# 1                  2990       27.75
# Test Set Class Distribution:
#                   Count  Percentage
# inadequate_sleep
# 0                  3336       72.24
# 1                  1282       27.76

# %%
# display the data after splitting

# Training set
display(pd.DataFrame(X_train).head())
display(pd.DataFrame(y_train).head())

# Test set
display(pd.DataFrame(X_test).head())
display(pd.DataFrame(y_test).head())
# Out:
#        K2Q01  ScreenTime_23  FoodCash_23  FamCount_23  AdultEduc_23
# 33411      3              3            1            4             2
# 3617       2              5            1            1             3
# 43104      1              3            1            2             4
# 51205      1              4            1            4             4
# 27558      1              3            2            4             4
#        inadequate_sleep
# 33411                 0
# 3617                  1
# 43104                 1
# 51205                 0
# 27558                 0
#        K2Q01  ScreenTime_23  FoodCash_23  FamCount_23  AdultEduc_23
# 5896       1              5            1            2             4
# 30050      2              5            3            2             4
# 23393      1              5            2            3             3
# 18335      1              3            1            5             4
# 26592      2              4            1            4             4
#        inadequate_sleep
# 5896                  0
# 30050                 0
# 23393                 0
# 18335                 0
# 26592                 0

# %%
# Do not need to scale the data for a naive Bayes analysis
# Displaying the training set

display(pd.DataFrame(X_train).head())
# Out:
#        K2Q01  ScreenTime_23  FoodCash_23  FamCount_23  AdultEduc_23
# 33411      3              3            1            4             2
# 3617       2              5            1            1             3
# 43104      1              3            1            2             4
# 51205      1              4            1            4             4
# 27558      1              3            2            4             4

# %%
# Implementing naive Bayes classifier

classifier = MultinomialNB(alpha=1.0) # Using default alpha for smoothing
classifier.fit(X_train, y_train, sample_weight = FWC_train)

#X_train - the training features whose values may induce insurance coverage thresholds
#y_train - the coorresponding targer variable (0 or 1) for the training features
# Out:
# MultinomialNB()

# %%
# Generating the confusion matrix

# Predictions
preds = classifier.predict(X_test)

# Compute weighted confusion matrix and weighted accuracy
conf_df = pd.DataFrame({
    'y_true': y_test,
    'y_pred': preds,
    'weight': FWC_test
})

# Group by true and predicted labels and sum weights
weighted_cm = conf_df.groupby(['y_true', 'y_pred'])['weight'].sum().unstack(fill_value=0)

# Ensure matrix shape is 2x2
weighted_cm = weighted_cm.reindex(index=[0,1], columns=[0,1], fill_value=0).values.astype(int)

acc = accuracy_score(y_test, preds, sample_weight=FWC_test)

# Class labels
labels = ["Adequate Sleep", "Inadequate Sleep"]

# Plot setup
plt.figure(figsize=(7,6))
ax = sns.heatmap(weighted_cm, annot=True, fmt='d',
                 cmap='YlGnBu',
                 linewidths=1.5, linecolor='white',
                 xticklabels=labels, yticklabels=labels,
                 cbar_kws={'shrink':0.8, 'label':'Count'},
                 annot_kws={'size':13, 'weight':'bold', 'color':'black'})

plt.title(f"Weighted Confusion Matrix: 0.5 Threshold — \nMultinomial Naive Bayes Classifier\nAccuracy: {acc:.2f}",
          fontsize=14, weight='bold', pad=15)
plt.xlabel("Predicted Label", fontsize=12, labelpad=10)
plt.ylabel("True Label", fontsize=12, labelpad=10)

# Label coordinates (slightly below numeric counts)
offset_y = 0.25  # small downward shift from center

# Overlay TN / FP / FN / TP *below* the numbers
for i in range(weighted_cm.shape[0]):
    for j in range(weighted_cm.shape[1]):
        if i == 0 and j == 0:
            label, color = "TN", "black"
        elif i == 0 and j == 1:
            label, color = "FP", "crimson"
        elif i == 1 and j == 0:
            label, color = "FN", "darkorange"
        else:
            label, color = "TP", "darkgreen"

        ax.text(j + 0.5, i + 0.5 + offset_y, label,
                color=color, fontsize=12, weight='bold',
                ha='center', va='center', alpha=0.9)

plt.tight_layout()

# Save plot
plt.savefig('Q9_AdeqSleep_MNB_CM_Original.png', dpi=300, bbox_inches='tight')

plt.show()

# more false positives (494,404), which is expected when lowering the threshold.
# This may be okay depending on the cost of false negatives in your problem (i.e., missing 
# teenagers who are not getting enough sleep).

# %%
print(weighted_cm)

#This is really terrible. Check that the variables are hte expected type and we aren't missing values
# Out:
# [[4367629       0]
#  [1769946       0]]

# %%
# Check for invalid values
print(X_train[features].dtypes)
print((X_train[features] < 0).sum())
print(X_train[features].isnull().sum())
print(X_train[features].map(lambda x: isinstance(x, float)).sum())
# Out:
# K2Q01            int64
# ScreenTime_23    int64
# FoodCash_23      int64
# FamCount_23      int64
# AdultEduc_23     int64
# dtype: object
# K2Q01            0
# ScreenTime_23    0
# FoodCash_23      0
# FamCount_23      0
# AdultEduc_23     0
# dtype: int64
# K2Q01            0
# ScreenTime_23    0
# FoodCash_23      0
# FamCount_23      0
# AdultEduc_23     0
# dtype: int64
# K2Q01            0
# ScreenTime_23    0
# FoodCash_23      0
# FamCount_23      0
# AdultEduc_23     0
# dtype: int64

# %%
# Get predicted probabilities for class 1 (inadequate sleep)
y_probs = classifier.predict_proba(X_test[features])[:, 1]

print("Predicted probability stats for class 1:")
print(f"Min: {y_probs.min():.4f}")
print(f"Max: {y_probs.max():.4f}")
print(f"Mean: {y_probs.mean():.4f}")
print(f"Threshold at 0.5: {(y_probs >= 0.5).sum()} instances")

# It looks like the threshold of 0.5 is too strick and causing us to have 
# zero instances of inadequate sleep
# Out:
# Predicted probability stats for class 1:
# Min: 0.2237
# Max: 0.3489
# Mean: 0.2767
# Threshold at 0.5: 0 instances

# %%
#Find a better threshold
thresholds = np.linspace(0.2, 0.5, 50)
f1s, recalls, accs = [], [], []

probs = classifier.predict_proba(X_test)[:, 1]

for t in thresholds:
    preds = (probs >= t).astype(int)
    f1s.append(f1_score(y_test, preds, sample_weight=FWC_test))
    recalls.append(recall_score(y_test, preds, sample_weight=FWC_test))
    accs.append(accuracy_score(y_test, preds, sample_weight=FWC_test))

plt.plot(thresholds, accs, label='Accuracy')
plt.plot(thresholds, recalls, label='Recall')
plt.plot(thresholds, f1s, label='F1-score')
plt.axvline(0.3, color='gray', linestyle='--', label='Selected threshold')
plt.xlabel("Threshold")
plt.ylabel("Score")
plt.title("Threshold Tuning for MultinomialNB")
plt.legend()
plt.grid(True)
plt.tight_layout()

# Save plot
plt.savefig('Q9_AdeqSleep_MNB_Threshold_Tuning.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score

precision, recall, thresholds = precision_recall_curve(y_test, probs, sample_weight=FWC_test)
ap_score = average_precision_score(y_test, probs, sample_weight=FWC_test)

plt.plot(recall, precision)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title(f"Precision-Recall Curve (AP = {ap_score:.3f})")
plt.grid(True)

# Save plot
plt.savefig('Q9_AdeqSleep_MNB_PrecRecall.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
# Final prediction logic using a threshold of 0.3
y_pred_final = (classifier.predict_proba(X_test)[:, 1] >= 0.3).astype(int)

# %%
# Generating the confusion matrix with revised threshold

# Predictions - replace cut off of 0.5 with 0.3 instead
probs = classifier.predict_proba(X_test)[:, 1]
threshold = 0.3
preds = (probs >= threshold).astype(int)

# Compute weighted confusion matrix and weighted accuracy
conf_df = pd.DataFrame({
    'y_true': y_test,
    'y_pred': preds,
    'weight': FWC_test
})

# Group by true and predicted labels and sum weights
weighted_cm = conf_df.groupby(['y_true', 'y_pred'])['weight'].sum().unstack(fill_value=0)

# Ensure matrix shape is 2x2
weighted_cm = weighted_cm.reindex(index=[0,1], columns=[0,1], fill_value=0).values.astype(int)

acc = accuracy_score(y_test, preds, sample_weight=FWC_test)

# Class labels
labels = ["Adequate Sleep", "Inadequate Sleep"]

# Plot setup
plt.figure(figsize=(7,6))
ax = sns.heatmap(weighted_cm, annot=True, fmt='d',
                 cmap='YlGnBu',
                 linewidths=1.5, linecolor='white',
                 xticklabels=labels, yticklabels=labels,
                 cbar_kws={'shrink':0.8, 'label':'Count'},
                 annot_kws={'size':13, 'weight':'bold', 'color':'black'})

plt.title(f"Weighted Confusion Matrix: 0.3 Threshold — \nMultinomial Naive Bayes Classifier\nAccuracy: {acc:.2f}",
          fontsize=14, weight='bold', pad=15)
plt.xlabel("Predicted Label", fontsize=12, labelpad=10)
plt.ylabel("True Label", fontsize=12, labelpad=10)

# Label coordinates (slightly below numeric counts)
offset_y = 0.25  # small downward shift from center

# Overlay TN / FP / FN / TP *below* the numbers
for i in range(weighted_cm.shape[0]):
    for j in range(weighted_cm.shape[1]):
        if i == 0 and j == 0:
            label, color = "TN", "black"
        elif i == 0 and j == 1:
            label, color = "FP", "crimson"
        elif i == 1 and j == 0:
            label, color = "FN", "darkorange"
        else:
            label, color = "TP", "darkgreen"

        ax.text(j + 0.5, i + 0.5 + offset_y, label,
                color=color, fontsize=12, weight='bold',
                ha='center', va='center', alpha=0.9)

plt.tight_layout()

# Save plot
plt.savefig('Q9_AdeqSleep_MNB_CM_ReviseThreshold.png', dpi=300, bbox_inches='tight')

plt.show()

# more false positives (494,404), which is expected when lowering the threshold.
# This may be okay depending on the cost of false negatives in your problem (i.e., missing 
# teenagers who are not getting enough sleep).

# %%
# Accuracy, F1 Score and Recall Score

# See final program for text on what these are

accuracy = accuracy_score(y_test, preds, sample_weight=FWC_test)
f1 = f1_score(y_test, preds, sample_weight=FWC_test)
recall = recall_score(y_test, preds, sample_weight=FWC_test)

print(f'Accuracy: {accuracy:.2f}')
print(f'F1 Score: {f1:.2f}')
print(f'Recall: {recall:.2f}')
# Out:
# Accuracy: 0.68
# F1 Score: 0.25
# Recall: 0.18

# %%
# Predict the test set probabilities of the positive class
y_pred_proba_rf = classifier.predict_proba(X_test)[:,1]
test_roc_auc_rf = roc_auc_score(y_test, y_pred_proba_rf, sample_weight=FWC_test)
# Print test_roc_auc
print('Test set ROC AUC score: {:.3f}'.format(test_roc_auc_rf))
# Out:
# Test set ROC AUC score: 0.592

# %%
## ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba_rf)

lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % test_roc_auc_rf)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic curve —\nMultinomial Naive Bayes Classifier \nwith a Target of Inadequate Sleep')
plt.legend(loc="lower right")

# Save plot
plt.savefig('Q9_AdeqSleep_MNB_ROC.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
print (classifier.get_params())
# Out:
# {'alpha': 1.0, 'class_prior': None, 'fit_prior': True, 'force_alpha': True}

# %%
#MultinomialNB does not have an attribute for feature importance
#However, can look at log probabilities 
#A positive score means the feature is more associated with class 1 (inadequate sleep).
#A negative score means it's more associated with class 0 (adequate sleep).
#The magnitude tells you how influential that feature is, but it’s not exactly the same as impurity-based importance.

# Get the log-probabilities for each feature per class
log_probs = classifier.feature_log_prob_

# Compute the difference between classes (e.g., log odds for class 1 vs 0)
feature_scores = log_probs[1] - log_probs[0]  # or vice versa

# Sort by importance (absolute log-odds)
indices = np.argsort(np.abs(feature_scores))[::-1]

# Visualize
plt.figure(figsize=(10, 6))
plt.title("Multinomial Naive Bayes Classifier with a Target of Inadequate Sleep:\n Feature Influence (log prob difference)", fontsize=14, weight='bold')
plt.bar(range(len(indices)), feature_scores[indices], align='center', color='skyblue')
plt.xticks(range(len(indices)), [features[i] for i in indices], rotation=45, ha='right', fontsize=12)
plt.xlabel("Features", fontsize=12)
plt.ylabel("Log Probability Difference", fontsize=12)
plt.axhline(0, color='grey', linestyle='--')
plt.tight_layout()

# Save plot
plt.savefig('Q9_AdeqSleep_MNB_LogProb.png', dpi=300, bbox_inches='tight')

plt.show()

# %% [markdown]
# ### Partial dependence plots
# Look for the directionality of the results.
#
# Partial dependence plots show the dependence between the target function and a set of ‘target’ features, marginalizing over the values of all other features (the complement features).

# %%
# Make sure 'features' is a list of 23 features (names or indices)
n_features = len(features)
ncols = 5
nrows = int(np.ceil(n_features / ncols))

# Create enough subplots (will likely have a few extra)
fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(ncols * 4, nrows * 3))

# Flatten the axes
ax = ax.flatten()

# Plot partial dependence
PartialDependenceDisplay.from_estimator(classifier, X_train, features, ax=ax[:n_features])

# Remove unused axes (if any)
for i in range(n_features, len(ax)):
    fig.delaxes(ax[i])

# Set title and layout
fig.suptitle('Partial Dependence of Inadequate Sleep on Features\n(Multinomial Naive Bayes)', fontsize=16)
fig.subplots_adjust(wspace=0.4, hspace=0.6)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
